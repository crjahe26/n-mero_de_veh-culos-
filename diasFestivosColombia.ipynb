# %%
# Fechas de los festivos: https://www.festivos.com.co/historico

import pandas as pd

# Crear un DataFrame vacío para almacenar los días festivos
festivos_colombia = pd.DataFrame(columns=['Fecha', 'NombreFeriado', 'DiaSemana'])

# Función para agregar días festivos a DataFrame
def agregar_festivos(year, fechas, nombres, dias_semana):
    global festivos_colombia  # Declarar la variable como global
    festivos_df = pd.DataFrame({
        'Fecha': pd.to_datetime(fechas),
        'NombreFeriado': nombres,
        'DiaSemana': dias_semana,
    })
    festivos_colombia = pd.concat([festivos_colombia, festivos_df])

# Añadir días festivos para el año 2011
agregar_festivos(2011, ['2011-01-01', '2011-01-10', '2011-03-21', '2011-04-21', '2011-04-22',
                             '2011-05-01', '2011-06-06', '2011-06-27', '2011-07-04', '2011-07-04',
                             '2011-07-20', '2011-08-07', '2011-08-15', '2011-10-17', '2011-11-07',
                             '2011-11-14', '2011-12-08', '2011-12-25'],
                        ['Año Nuevo', 'Día de Reyes', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                      'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'Sagrado Corazón de Jesús',
                      'San Pedro y San Pablo', 'Día de la independencia', 'Batalla de Boyacá',
                      'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                      'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                      ['Sábado', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Domingo', 'Lunes', 'Lunes', 'Lunes',
                   'Lunes', 'Miércoles', 'Domingo', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Jueves', 'Domingo']
                )

# Añadir días festivos para el año 2012
agregar_festivos(2012, ['2012-01-01', '2012-01-09', '2012-03-19', '2012-04-05', '2012-04-06',
                             '2012-05-01', '2012-05-21', '2012-06-11', '2012-06-18', '2012-07-02',
                             '2012-07-20', '2012-08-07', '2012-08-20', '2012-10-15', '2012-11-05',
                             '2012-11-12', '2012-12-08', '2012-12-25'],
                        ['Año Nuevo', 'Epifanía', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                      'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'Sagrado Corazón de Jesús',
                      'San Pedro y San Pablo', 'Día de la independencia', 'Batalla de Boyacá',
                      'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                      'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                      ['Domingo', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Martes', 'Lunes', 'Lunes', 'Lunes',
                  'Lunes', 'Viernes', 'Martes', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Sábado', 'Martes']     
                             )


# Añadir días festivos para el año 2013
agregar_festivos(2013, ['2013-01-01', '2013-01-07', '2013-03-25', '2013-03-28', '2013-03-29',
                             '2013-05-01', '2013-05-13', '2013-06-03', '2013-06-10', '2013-07-01',
                             '2013-07-20', '2013-08-07', '2013-08-19', '2013-10-14', '2013-11-04',
                             '2013-11-11', '2013-12-08', '2013-12-25'],
                        ['Año Nuevo', 'Epifanía', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                      'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'Sagrado Corazón de Jesús',
                      'San Pedro y San Pablo', 'Día de la independencia', 'Batalla de Boyacá',
                      'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                      'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                      ['Martes', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Miércoles', 'Lunes', 'Lunes', 'Lunes',
                  'Lunes', 'Sábado', 'Miércoles', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Domingo', 'Miércoles']     
                             )


# Añadir días festivos para el año 2014
agregar_festivos(2014, ['2014-01-01', '2014-01-06', '2014-03-24', '2014-04-17', '2014-04-18',
                        '2014-05-01', '2014-06-02', '2014-06-23', '2014-06-30', '2014-06-30',
                        '2014-07-20', '2014-08-07', '2014-08-18', '2014-10-13', '2014-11-03',
                        '2014-11-17', '2014-12-08', '2014-12-25'],
                       ['Año Nuevo', 'Epifanía', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                        'Sagrado Corazón de Jesús', 'Día de la independencia', 'Batalla de Boyacá',
                        'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'San Pedro y San Pablo',
                        'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                        'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                       ['Miércoles', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Jueves', 'Lunes', 'Lunes', 'Lunes',
                        'Lunes', 'Domingo', 'Jueves', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Jueves']     
)


# Añadir días festivos para el año 2015
agregar_festivos(2015, ['2015-01-01', '2015-01-12', '2015-03-23', '2015-04-02', '2015-04-03',
                        '2015-05-01', '2015-05-18', '2015-06-08', '2015-06-15', '2015-06-29',
                        '2015-07-20', '2015-08-07', '2015-08-17', '2015-10-12', '2015-11-02',
                        '2015-11-16', '2015-12-08', '2015-12-25'],
                  ['Año Nuevo', 'Epifanía', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                   'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'Sagrado Corazón de Jesús',
                   'San Pedro y San Pablo', 'Día de la independencia', 'Batalla de Boyacá',
                   'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                   'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                   ['Jueves', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Viernes', 'Lunes', 'Lunes', 'Lunes',
                        'Lunes', 'Lunes', 'Viernes', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Martes', 'Viernes']  
                  )

# Añadir días festivos para el año 2016
agregar_festivos(2016, ['2016-01-01', '2016-01-11', '2016-03-21', '2016-03-24', '2016-03-25',
                        '2016-05-01', '2016-05-09', '2016-05-30', '2016-06-06', '2016-07-04',
                        '2016-07-20', '2016-08-07', '2016-08-15', '2016-10-17', '2016-11-07',
                        '2016-11-14', '2016-12-08', '2016-12-25'],
                  ['Año Nuevo', 'Epifanía', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                   'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'Sagrado Corazón de Jesús',
                   'San Pedro y San Pablo', 'Día de la independencia', 'Batalla de Boyacá',
                   'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                   'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                  ['Viernes', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Domingo', 'Lunes', 'Lunes', 'Lunes',
                   'Lunes', 'Miércoles', 'Domingo', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Jueves', 'Domingo'])

# Añadir días festivos para el año 2017
agregar_festivos(2017, ['2017-01-01', '2017-01-09', '2017-03-20', '2017-04-13', '2017-04-14',
                        '2017-05-01', '2017-05-29', '2017-06-19', '2017-06-26', '2017-07-03',
                        '2017-07-20', '2017-08-07', '2017-08-21', '2017-10-16', '2017-11-06',
                        '2017-11-13', '2017-12-08', '2017-12-25'],
                  ['Año Nuevo', 'Epifanía', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                   'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'Sagrado Corazón de Jesús',
                   'San Pedro y San Pablo', 'Día de la independencia', 'Batalla de Boyacá',
                   'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                   'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                  ['Domingo', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Lunes', 'Lunes', 'Lunes', 'Lunes',
                   'Lunes', 'Jueves', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Viernes', 'Lunes'])

# Añadir días festivos para el año 2018
agregar_festivos(2018, ['2018-01-01', '2018-01-08', '2018-03-19', '2018-03-29', '2018-03-30',
                        '2018-05-01', '2018-05-14', '2018-06-04', '2018-06-11', '2018-07-02',
                        '2018-07-20', '2018-08-07', '2018-08-20', '2018-10-15', '2018-11-05',
                        '2018-11-12', '2018-12-08', '2018-12-25'],
                  ['Año Nuevo', 'Epifanía', 'Día de San José', 'Jueves Santo', 'Viernes Santo',
                   'Día del trabajo', 'Ascensión de Jesús', 'Corpus Christi', 'Sagrado Corazón de Jesús',
                   'San Pedro y San Pablo', 'Día de la independencia', 'Batalla de Boyacá',
                   'Asunción de la Virgen', 'Día de la raza', 'Todos los Santos',
                   'Independencia de Cartagena', 'Inmaculada Concepción', 'Navidad'],
                  ['Lunes', 'Lunes', 'Lunes', 'Jueves', 'Viernes', 'Martes', 'Lunes', 'Lunes', 'Lunes',
                   'Lunes', 'Viernes', 'Martes', 'Lunes', 'Lunes', 'Lunes', 'Lunes', 'Sábado', 'Martes'])

# Guardar el DataFrame en un archivo CSV
festivos_colombia.to_csv('dias_festivos_colombia_2011_2018.csv', index=False)
# Out:
# /tmp/ipykernel_9158/2062108776.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   festivos_colombia = pd.concat([festivos_colombia, festivos_df])
